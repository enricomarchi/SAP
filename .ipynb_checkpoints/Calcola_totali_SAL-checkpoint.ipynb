# %%
ribasso = 15.95 
nome_file = "SAL.xlsx"
ed_tariffa = "ed_2022_05"

# %%
import pandas as pd
import numpy as np
import locale
df = pd.read_excel(nome_file)
tariffe = pd.read_parquet("Tariffe.parquet")
df_tot = df.merge(tariffe[["Numero_S_VdT", ed_tariffa]], left_on="VDT", right_on="Numero_S_VdT", how="left").drop("Numero_S_VdT", axis=1)
df_tot["Pr_tot"] = np.where(df_tot["NV"].isna(), 
                            df_tot["Quantità"] * df_tot[ed_tariffa], 
                            df_tot["Quantità"] * df_tot["Prezzo"])
df_os = df_tot[df_tot['VDT'].str.startswith("OS")]
df_prog = df_tot[df_tot['VDT'].str.contains("DM 17.06.2016 n.50", na=False)]

importo_tot_prog = round(df_prog["Pr_tot"].sum(), 2) 
importo_tot_os = round(df_os["Pr_tot"].sum(), 2)
importo_tot_lavori = df_tot["Pr_tot"].sum() - importo_tot_prog - importo_tot_os
importo_tot_lordo = importo_tot_prog + importo_tot_os + importo_tot_lavori
importo_ribasso = round((importo_tot_lavori + importo_tot_prog) * (ribasso/100), 2)
importo_netto_lavori_prog = importo_tot_lavori + importo_tot_prog - importo_ribasso
importo_netto_tot = importo_netto_lavori_prog + importo_tot_os

allineamento = 15

locale.setlocale(locale.LC_ALL, 'it_IT.utf8')
f_ribasso = locale.format_string("%.3f", ribasso, grouping=True)
f_importo_tot_lavori = locale.format_string("%.2f", importo_tot_lavori, grouping=True)
f_importo_tot_prog = locale.format_string("%.2f", importo_tot_prog, grouping=True)
f_importo_tot_os = locale.format_string("%.2f", importo_tot_os, grouping=True)
f_importo_tot_lordo = locale.format_string("%.2f", importo_tot_lordo, grouping=True)
f_importo_ribasso = locale.format_string("%.2f", importo_ribasso, grouping=True)
f_importo_netto_lavori_prog = locale.format_string("%.2f", importo_netto_lavori_prog, grouping=True)
f_importo_netto_tot = locale.format_string("%.2f", importo_netto_tot, grouping=True)
print(f"Importo lordo lavori                      = {f_importo_tot_lavori.rjust(allineamento)}\n"
      f"Importo progettazione                     = {f_importo_tot_prog.rjust(allineamento)}\n"
      f"Importo oneri sicurezza                   = {f_importo_tot_os.rjust(allineamento)}\n"
      f"\033[1m\033[46mImporto totale lordo                      = {f_importo_tot_lordo.rjust(allineamento)}\033[0m\n"
      f"Importo ribasso del {f_ribasso} %              = {f_importo_ribasso.rjust(allineamento)}\n"
      f"Importo netto solo lavori e progettazione = {f_importo_netto_lavori_prog.rjust(allineamento)}\n"
      f"\033[1m\033[43mImporto totale al netto del ribasso       = {f_importo_netto_tot.rjust(allineamento)}\033[0m\n"    
     )
# Out:
# Importo lordo lavori                      =       59.450,18
# Importo progettazione                     =            0,00
# Importo oneri sicurezza                   =          774,72
# Importo totale lordo                      =       60.224,90
# Importo ribasso del 15,950 %              =        9.482,30
# Importo netto solo lavori e progettazione =       49.967,88
# Importo totale al netto del ribasso       =       50.742,60

# %%
ed_tariffa_compensazione = "ed_2023"
# ------------------------------------- CALCOLO COMPENSAZIONI ------------------------------------------------
c_df_tot = df.merge(tariffe[["Numero_S_VdT", ed_tariffa_compensazione]], left_on="VDT", right_on="Numero_S_VdT", how="left").drop("Numero_S_VdT", axis=1)
c_df_tot["Pr_tot"] = np.where(c_df_tot["NV"].isna(), 
                            c_df_tot["Quantità"] * c_df_tot[ed_tariffa_compensazione], 
                            c_df_tot["Quantità"] * c_df_tot["Prezzo"])
c_df_os = c_df_tot[c_df_tot['VDT'].str.startswith("OS")]
c_df_prog = c_df_tot[c_df_tot['VDT'].str.contains("DM 17.06.2016 n.50", na=False)]

df_tot[ed_tariffa_compensazione] = c_df_tot[ed_tariffa_compensazione]
df_tot["Pr_tot_2023"] = c_df_tot["Pr_tot"]
df_tot["Diff"] = c_df_tot["Pr_tot"] - df_tot["Pr_tot"]
df_tot["_90_perc"] = df_tot["Diff"] * 0.9

# %%
df_tot
# Out:
#            ODA  Posizione  PO        Descrizione_PO  Descrizione  \
# 0   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 1   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 2   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 3   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 4   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 5   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 6   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 7   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 8   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 9   5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 10  5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 11  5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 12  5042121189         20  34  CA36_2022 AQ275_2019          NaN
# 13  5042121189         20  34  CA36_2022 AQ275_2019          NaN
#
#                VDT  Quantità  NV  Prezzo Rib        Data  Ed_Tariffa Inserita  \
# 0   TC.LV.C.3 06.A        16 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 1   TC.GD.D.3105.C        28 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 2   TC.LV.C.6 05.A        16 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 3   TC.PM.F.2 04.B      2366 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 4   TC.GD.D.3101.A         8 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 5   TC.GD.D.3101.B         8 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 6   TC.GD.D.3101.D         2 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 7   TC.GD.D.3101.J         2 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 8   TC.GD.D.3101.K         6 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 9   TC.LV.A.2 09.B     13618 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 10  TC.LV.A.2 09.B      4454 NaN     NaN  SI  15.07.2023  ed_2022_05        x
# 11  OS.AP.A.0103.A        39 NaN     NaN  NO  15.07.2023  ed_2022_05        x
# 12  OS.AP.A.0106.A       213 NaN     NaN  NO  15.07.2023  ed_2022_05        x
# 13  OS.IF.A.0102.A         1 NaN     NaN  NO  15.07.2023  ed_2022_05        x
#
#     ed_2022_05    Pr_tot  ed_2023  Pr_tot_2023    Diff  _90_perc
# 0        56.69    907.04    62.52      1000.32   93.28    83.952
# 1       393.97  11031.16   400.41     11211.48  180.32   162.288
# 2        63.67   1018.72    67.18      1074.88   56.16    50.544
# 3         3.65   8635.90     3.88      9180.08  544.18   489.762
# 4       761.59   6092.72   791.13      6329.04  236.32   212.688
# 5       854.44   6835.52   888.62      7108.96  273.44   246.096
# 6      1040.16   2080.32  1083.61      2167.22   86.90    78.210
# 7      1225.87   2451.74  1278.60      2557.20  105.46    94.914
# 8      1411.59   8469.54  1473.59      8841.54  372.00   334.800
# 9         0.66   8987.88     0.69      9396.42  408.54   367.686
# 10        0.66   2939.64     0.69      3073.26  133.62   120.258
# 11       10.53    410.67    10.09       393.51  -17.16   -15.444
# 12        0.75    159.75     0.69       146.97  -12.78   -11.502
# 13      204.30    204.30   214.49       214.49   10.19     9.171

# %%
somma_positivi = df_tot.loc[df_tot["_90_perc"] > 0, "_90_perc"].sum().round(2)
somma_positivi
# Out:
# 2250.37

# %%
somma_negativi = df_tot.loc[df_tot["_90_perc"] < 0, "_90_perc"].sum().round(2)
somma_negativi
# Out:
# -26.95

# %%
totale_positivi_piu_negativi = somma_positivi + somma_negativi
totale_positivi_piu_negativi
# Out:
# 2223.42
